# %%
import os
import re
import cv2
import pytesseract
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
def extract_text(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Increase contrast
    gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)

    # Slight threshold helps dates a lot
    _, thresh = cv2.threshold(gray, 180, 255, cv2.THRESH_BINARY)

    config = r"--oem 3 --psm 6"
    return pytesseract.image_to_string(thresh, config=config)

# %%
def detect_signature_cnn(image_path, threshold=0.5):
    """
    Visual signature detection using CNN.
    """
    img = cv2.imread(image_path)
    if img is None:
        return False

    h, w, _ = img.shape

    # Bottom-right area where signatures usually appear
    roi = img[int(h*0.65):h, int(w*0.4):w]

    roi = cv2.resize(roi, (128, 128))
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    roi = roi / 255.0
    roi = roi.reshape(1, 128, 128, 1)

    prob = signature_model.predict(roi, verbose=0)[0][0]
    return prob >= threshold

# %%
import re

MONTHS = (
    "jan|january|feb|february|mar|march|apr|april|may|"
    "jun|june|jul|july|aug|august|sep|september|"
    "oct|october|nov|november|dec|december"
)

SHORT_MONTHS = "jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec"

def detect_date(text):
    t = text.lower()

    # 1. Date keywords (important!)
    date_keywords = [
        "date:", "date :", "payment date", "invoice date", "bill date"
    ]

    if any(k in t for k in date_keywords):
        return True

    # 2. Month words (short + full)
    months = (
        "jan|january|feb|february|mar|march|apr|april|may|"
        "jun|june|jul|july|aug|august|sep|september|"
        "oct|october|nov|november|dec|december"
    )

    patterns = [
        # 3 April 2025
        rf"\b\d{{1,2}}\s*({months})\s*\d{{4}}\b",

        # April 3, 2025
        rf"\b({months})\s*\d{{1,2}},?\s*\d{{4}}\b",

        # 23 Mar 2025
        rf"\b\d{{1,2}}\s*(jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec)\s*\d{{4}}\b",

        # 01/25/2026 or 1-1-26
        r"\b\d{1,2}[/-]\d{1,2}[/-]\d{2,4}\b",

        # 2026-01-25
        r"\b\d{4}[/-]\d{1,2}[/-]\d{1,2}\b"
    ]

    for p in patterns:
        if re.search(p, t):
            return True

    return False

def extract_features(text):
    t = text.lower()

    has_date = bool(re.search(rf"\b({MONTHS})|\d{{1,2}}[/-]\d{{1,2}}", t))
    has_name = any(k in t for k in ["co.,", "co.", "company", "ltd", "limited",
        "supply", "shop", "bakery", "restaurant",
        "coffee", "flowers", "service", "center",
        "office", "book", "copy", "printing"])
    has_item = any(k in t for k in ["description", "qty", "amount", "total"])
    has_signature = any(k in t for k in ["signature", "received by", "authorized"])
    has_mfu = "mae fah luang" in t or "mfu" in t

    return [
        int(has_date),
        int(has_name),
        int(has_item),
        int(has_signature),
        int(has_mfu),
        len(t),
        sum(c.isdigit() for c in t)
    ]

# %%
X = []
y = []

for label, folder in [(1, "data/complete"), (0, "data/incomplete")]:
    for img in os.listdir(folder):
        if img.lower().endswith(".jpg"):
            path = os.path.join(folder, img)
            text = extract_text(path)
            X.append(extract_features(text))
            y.append(label)

X = np.array(X)
y = np.array(y)

# %%
def evaluate_model(model, X, y):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    acc, prec, rec, f1 = [], [], [], []
    cms = []

    for train, test in skf.split(X, y):
        model.fit(X[train], y[train])
        pred = model.predict(X[test])

        acc.append(accuracy_score(y[test], pred))
        prec.append(precision_score(y[test], pred))
        rec.append(recall_score(y[test], pred))
        f1.append(f1_score(y[test], pred))
        cms.append(confusion_matrix(y[test], pred))

    return {
        "Accuracy": np.mean(acc),
        "Precision": np.mean(prec),
        "Recall": np.mean(rec),
        "F1": np.mean(f1),
        "Confusion Matrix": np.sum(cms, axis=0)
    }

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(max_depth=5),
    "KNN": KNeighborsClassifier(n_neighbors=5),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42)
}

for name, model in models.items():
    results = evaluate_model(model, X, y)
    print(f"\n{name}")
    for k, v in results.items():
        print(k, ":", v)
# Out:
# /Users/doublenk/Desktop/receipt_project/venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Logistic Regression
# Accuracy : 0.5
# Precision : 0.4666666666666667
# Recall : 0.5
# F1 : 0.4466666666666666
# Confusion Matrix : [[5 5]
#  [5 5]]
#
# Decision Tree
# Accuracy : 0.45
# Precision : 0.4333333333333333
# Recall : 0.6
# F1 : 0.49333333333333335
# Confusion Matrix : [[3 7]
#  [4 6]]
#
# KNN
# Accuracy : 0.45
# Precision : 0.5333333333333333
# Recall : 0.6
# F1 : 0.5266666666666666
# Confusion Matrix : [[3 7]
#  [4 6]]
#
# Random Forest
# Accuracy : 0.35
# Precision : 0.3333333333333333
# Recall : 0.5
# F1 : 0.39333333333333337
# Confusion Matrix : [[2 8]
#  [5 5]]

# %%
def detect_vendor_name(text):
    t = text.lower()
    keywords = [
        "company", "co.", "ltd", "limited",
        "service", "bakery", "coffee", "restaurant",
        "supply", "center", "shop", "book", "hotel"
    ]
    return any(k in t for k in keywords)

# %%
def detect_item_list(text):
    t = text.lower()
    return any(k in t for k in [
        "description", "qty", "quantity",
        "unit price", "amount", "total"
    ])

# %%
def detect_mfu_address(text):
    t = text.lower()
    return "mae fah luang university" in t or "mfu" in t

# %%
def detect_signature_ocr(text):
    """
    OCR-based signature detection.
    WARNING: Cannot detect handwritten signatures reliably.
    """
    t = text.lower()
    keywords = [
        "signature",
        "signed by",
        "received by",
        "authorized by",
        "approved by",
        "cashier",
        "manager"
    ]
    return any(k in t for k in keywords)

# %%
def analyze_receipt(text):
    missing = []

    if not detect_vendor_name(text):
        missing.append("Name")

    if not detect_date(text):     
        missing.append("Date")

    if not detect_item_list(text):
        missing.append("Item list")

    if not detect_mfu_address(text):
        missing.append("MFU address")

    if not detect_signature_ocr(text):
        missing.append("Signature")
    if not detect_signature_cnn(image_path):
        missing.append("Signature")

    return missing

# %%
def run_all_receipts():
    print("=== COMPLETE RECEIPTS ===")
    for img in sorted(os.listdir("data/complete")):
        if img.lower().endswith(".jpg"):
            path = os.path.join("data/complete", img)
            text = extract_text(path)
            missing = analyze_receipt(text)

            print(f"Receipt: {img}")
            if not missing:
                print("Prediction: COMPLETE")
                print("No missing parts")
            else:
                print("Prediction: INCOMPLETE")
                print("Possible missing field(s):")
                for m in missing:
                    print("-", m)
            print("-" * 40)

    print("\n=== INCOMPLETE RECEIPTS ===")
    for img in sorted(os.listdir("data/incomplete")):
        if img.lower().endswith(".jpg"):
            path = os.path.join("data/incomplete", img)
            text = extract_text(path)
            missing = analyze_receipt(text)

            print(f"Receipt: {img}")
            print("Prediction: INCOMPLETE")
            if missing:
                print("Possible missing field(s):")
                for m in missing:
                    print("-", m)
            else:
                print("No missing parts detected")
            print("-" * 40)

# %%
run_all_receipts()
# Out:
# === COMPLETE RECEIPTS ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 run_all_receipts()
#
# Cell In[100], line 7, in run_all_receipts()
#       5 path = os.path.join("data/complete", img)
#       6 text = extract_text(path)
# ----> 7 missing = analyze_receipt(text)
#       9 print(f"Receipt: {img}")
#      10 if not missing:
#
# Cell In[99], line 16, in analyze_receipt(text)
#      13 if not detect_mfu_address(text):
#      14     missing.append("MFU address")
# ---> 16 if not detect_signature_ocr(text):
#      17     missing.append("Signature")
#      18 if not detect_signature_cnn(image_path):
#
# NameError: name 'detect_signature_ocr' is not defined
